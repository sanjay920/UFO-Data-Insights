# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/UFO_sightings.csv')

# %%
list(df)
# Out:
# ['id',
#  'description',
#  'duration',
#  'location',
#  'reported_at',
#  'shape',
#  'sighted_at',
#  'geocoded_latitude',
#  'geocoded_longitude',
#  'city',
#  'state',
#  'country',
#  'closest_LARGE_airport_distance',
#  'closest_MEDIUM_airport_distance',
#  'closest_SMALL_airport_distance',
#  'closest_metro_distance',
#  'closest_metro_pop',
#  'closest_metro_m4',
#  'closest_metro_m6',
#  'population',
#  'meteor_sighting',
#  'text',
#  'lat',
#  'lon',
#  'named_entities',
#  'date',
#  'Country',
#  'URL',
#  'Captions',
#  'Class',
#  'Class_1',
#  'Class_2',
#  'Class_3',
#  'Class_4',
#  'Class_5',
#  'Class_6',
#  'Class_7']

# %%
df[['id', 'geocoded_latitude', 'geocoded_longitude']].rename(index=str, columns={"A": "a", "B": "c"}).to_csv('sightings.csv', index=False)
# Out:
#          id  geocoded_latitude  geocoded_longitude
# 0         0          41.661256          -91.529911
# 1         1          43.034993          -87.922497
# 2         2          47.215094         -123.100707
# 3         3          38.951883          -92.333737
# 4         4          47.603832         -122.330062
# 5         6          46.877229          -96.789821
# 6         7          36.166286         -115.149225
# 7         8          39.909835          -75.323521
# 8         9          47.669414         -122.123877
# 9        10          47.479908         -122.203450
# 10       11          39.798976          -89.644369
# 11       12          42.123710          -71.178663
# 12       13          41.423967          -76.494113
# 13       14          33.732052          -84.919108
# 14       15          46.686484         -123.732947
# 15       16          28.542400          -81.379437
# 16       17          36.791225          -81.771232
# ...
